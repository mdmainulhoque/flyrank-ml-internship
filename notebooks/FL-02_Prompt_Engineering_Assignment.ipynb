# %% [markdown]
# # FL-02 Prompt Engineering Assignment
#
# **Topic:** SEO Dataset Analysis for FlyRank AI

# %% [markdown]
# ## Task Description
# Analyze an SEO dataset and improve the prompt through multiple iterations.

# %% [markdown]
# ## Version 0 (Naive Prompt)
#
# ### Prompt
# ```
# Analyze this SEO dataset and tell me the best keywords.
# ```
#
# ### Output
# Paste the output here.
#
# ### Iteration Note
# Baseline prompt with no context.

# %% [markdown]
# ## Version 1 (Role Assignment)
#
# ### Prompt
# ```
# You are an experienced SEO Data Analyst.
#
# Analyze the attached dataset and identify the top keyword opportunities.
#
# Explain why each keyword is valuable.
# ```
#
# ### Output
# Paste the output here.
#
# ### Iteration Note
# Role assignment made the response more professional.

# %% [markdown]
# ## Version 2 (Context)
#
# ### Prompt
# ```
# You are an SEO Data Analyst working for FlyRank AI.
#
# The dataset contains search volume, competition, CPC, keyword intent, and content type.
#
# Identify keywords with high search volume, low competition, high CPC, and commercial intent.
# ```
#
# ### Output
# Paste the output here.
#
# ### Iteration Note
# Added context improved relevance.

# %% [markdown]
# ## Version 3 (Few-shot)
#
# ### Prompt
# ```
# Example
#
# Keyword: AI Writing Tool
# Search Volume: 22000
# Competition: Low
# CPC: $2.50
#
# Recommendation:
# Good opportunity because demand is high while competition remains low.
#
# Now analyze the dataset in the same format.
# ```
#
# ### Output
# Paste the output here.
#
# ### Iteration Note
# Few-shot example improved consistency.

# %% [markdown]
# ## Version 4 (Structured Output)
#
# ### Prompt
# ```
# Return results as a markdown table with columns:
#
# Keyword
# Search Volume
# Competition
# CPC
# Intent
# Opportunity Score
# Recommendation
# Reason
# ```
#
# ### Output
# Paste the output here.
#
# ### Iteration Note
# Structured output made results easier to read.

# %% [markdown]
# ## Version 5 (Step-by-Step)
#
# ### Prompt
# ```
# Follow these steps:
#
# 1. Read dataset
# 2. Clean invalid rows
# 3. Rank keywords
# 4. Assign Opportunity Score
# 5. Recommend Top 20
# 6. Explain recommendations
# ```
#
# ### Output
# Paste the output here.
#
# ### Iteration Note
# Step decomposition improved reasoning.

# %% [markdown]
# ## Claude vs ChatGPT Comparison
#
# | Feature | ChatGPT | Claude |
# |---|---|---|
# | Accuracy | | |
# | Structure | | |
# | Tone | | |
# | Detail | | |
# | Weakness | | |

# %% [markdown]
# ## Final Reusable Prompt
#
# ```text
# You are a senior SEO Data Scientist working at FlyRank AI.
#
# Your task is to analyze the attached SEO dataset.
#
# 1. Clean invalid data.
# 2. Rank keywords using search volume, competition, CPC, and intent.
# 3. Assign an Opportunity Score (1–10).
# 4. Recommend the Top 20 keywords.
# 5. Explain every recommendation.
# 6. Present everything in a markdown table.
#
# Return a professional SEO strategy report.
# ```
